# %% [markdown]
# # Categorizing all the tariff data China announced and write them into excel sheet.

# %%
'''Categorizing all the tariff data China announced and write them into excel sheet.'''

import re
import xlsxwriter

'''two txt files''' 
#china.txt
#us.txt

china = open('china.txt')
rchina = china.read()

#return all the commodity categories, names and volumes
cm = re.findall('<li class=item__(.*?) data-dollareffect=(.*?)> <span class=item__bullet>•</span> <span class=item__name>(.*?)</span> </li>',rchina,re.DOTALL)

#seperate the list above by category
alist = list()
for ia in cm:
    if ia[0] == 'agriculture':
        alist.append(ia)
elist = list()
for ie in cm:
    if ie[0] == 'energy':
        elist.append(ie)
ilist = list()
for ii in cm:
    if ii[0] == 'industrials':
        ilist.append(ii)
tlist = list()
for it in cm:
    if it[0] == 'transport':
        tlist.append(it)
olist = list()
for io in cm:
    if io[0] == 'others':
        olist.append(io)

#get total number of each categories' commodities  
lcma=len(alist)
lcme=len(elist)
lcmi=len(ilist)
lcmt=len(tlist)
lcmo=len(olist)

#return all the dollar volumes into 5 lists seperated based on catergories
#and convert all the dollar volume into integer
anumlist = list()
for aitem in alist:
    anum = aitem[1]
    anumlist.append(anum)
anumlist2 =list()
for aitem2 in anumlist:
    if aitem2 == '""':
        aitem2 = int(0)
        anumlist2.append(int(aitem2))
    else:
        aitem2 == aitem2
        anumlist2.append(int(aitem2))

enumlist = list()
for eitem in elist:
    enum = eitem[1]
    enumlist.append(enum)
enumlist2 =list()
for eitem2 in enumlist:
    if eitem2 == '""':
        eitem2 = int(0)
        enumlist2.append(int(eitem2))
    else:
        eitem2 == eitem2
        enumlist2.append(int(eitem2))

inumlist = list()
for iitem in ilist:
    inum = iitem[1]
    inumlist.append(inum)
inumlist2 =list()
for iitem2 in inumlist:
    if iitem2 == '""':
        iitem2 = int(0)
        inumlist2.append(int(iitem2))
    else:
        iitem2 == iitem2
        inumlist2.append(int(iitem2))        
        
tnumlist = list()
for titem in tlist:
    tnum = titem[1]
    tnumlist.append(tnum)
tnumlist2 =list()
for titem2 in tnumlist:
    if titem2 == '""':
        titem2 = int(0)
        tnumlist2.append(int(titem2))
    else:
        titem2 == titem2
        tnumlist2.append(int(titem2))
        
onumlist = list()
for oitem in olist:
    onum = oitem[1]
    onumlist.append(onum)
onumlist2 =list()
for oitem2 in onumlist:
    if oitem2 == '""':
        oitem2 = int(0)
        onumlist2.append(int(oitem2))
    else:
        oitem2 == oitem2
        onumlist2.append(int(oitem2))        
        
#return all the commodity names into 5 lists seperated based on catergories
acomlist = list()
for ac in alist:
    acom = ac[2]
    acomlist.append(acom)
ecomlist = list()
for ec in elist:
    ecom = ec[2]
    ecomlist.append(ecom)
icomlist = list()
for ic in ilist:
    icom = ic[2]
    icomlist.append(icom)
tcomlist = list()
for tc in tlist:
    tcom = tc[2]
    tcomlist.append(tcom)
ocomlist = list()
for oc in olist:
    ocom = oc[2]
    ocomlist.append(ocom)

    
#convert the volume and name back together into one list of tuple, for the preparation of sorting
#after finishing sorting, seperate the volume and name items again into 2 lists
forsortinga = zip(anumlist2,acomlist)
forsortinga = set(forsortinga)
sortinga = sorted(forsortinga, key=lambda fa: fa[0], reverse = True)
sanumlist = list()    
sacomlist = list()
for saitem in sortinga:
    sanum = saitem[0]
    sanumlist.append(sanum)
for sac in sortinga:
    sacom = sac[1]
    sacomlist.append(sacom)

forsortinge = zip(enumlist2,ecomlist)
forsortinge = set(forsortinge)
sortinge = sorted(forsortinge, key=lambda fe: fe[0], reverse = True)
senumlist = list()    
secomlist = list()
for seitem in sortinge:
    senum = seitem[0]
    senumlist.append(senum)
for sec in sortinge:
    secom = sec[1]
    secomlist.append(secom)   

forsortingi = zip(inumlist2,icomlist)
forsortingi = set(forsortingi)
sortingi = sorted(forsortingi, key=lambda fi: fi[0], reverse = True)
sinumlist = list()    
sicomlist = list()
for siitem in sortingi:
    sinum = siitem[0]
    sinumlist.append(sinum)
for sic in sortingi:
    sicom = sic[1]
    sicomlist.append(sicom) 
    
forsortingt = zip(tnumlist2,tcomlist)
forsortingt = set(forsortingt)
sortingt = sorted(forsortingt, key=lambda ft: ft[0], reverse = True)
stnumlist = list()    
stcomlist = list()
for stitem in sortingt:
    stnum = stitem[0]
    stnumlist.append(stnum)
for stc in sortingt:
    stcom = stc[1]
    stcomlist.append(stcom) 
    
forsortingo = zip(onumlist2,ocomlist)
forsortingo = set(forsortingo)
sortingo = sorted(forsortingo, key=lambda fo: fo[0], reverse = True)
sonumlist = list()    
socomlist = list()
for soitem in sortingo:
    sonum = soitem[0]
    sonumlist.append(sonum)
for soc in sortingo:
    socom = soc[1]
    socomlist.append(socom) 

#write all the content and number into a excel book
workbook = xlsxwriter.Workbook('tariffs2.xlsx')
worksheet1 = workbook.add_worksheet('tchina')

worksheet1.write(0,0,'AGRICULTURE')
worksheet1.write(0,1,lcma)
worksheet1.write(1,0,'Commodity')
worksheet1.write(1,1,'Dollar Volume')
worksheet1.write_column(2,1,sanumlist)
worksheet1.write_column(2,0,sacomlist)

worksheet1.write(0,2,'ENERGY')
worksheet1.write(0,3,lcme)
worksheet1.write(1,2,'Commodity')
worksheet1.write(1,3,'Dollar Volume')
worksheet1.write_column(2,3,senumlist)
worksheet1.write_column(2,2,secomlist)

worksheet1.write(0,4,'INDUSTRIALS/TECHNOLOGY')
worksheet1.write(0,5,lcmi)
worksheet1.write(1,4,'Commodity')
worksheet1.write(1,5,'Dollar Volume')
worksheet1.write_column(2,5,sinumlist)
worksheet1.write_column(2,4,sicomlist)

worksheet1.write(0,6,'TRANSPORT')
worksheet1.write(0,7,lcmt)
worksheet1.write(1,6,'Commodity')
worksheet1.write(1,7,'Dollar Volume')
worksheet1.write_column(2,7,stnumlist)
worksheet1.write_column(2,6,stcomlist)

worksheet1.write(0,8,'OTHERS')
worksheet1.write(0,9,lcmo)
worksheet1.write(1,8,'Commodity')
worksheet1.write(1,9,'Dollar Volume')
worksheet1.write_column(2,9,sonumlist)
worksheet1.write_column(2,8,socomlist)

#workbook.close()
# Out:
# 0

# %% [markdown]
# # Categorizing all the tariff data US announced and write them into excel sheet.

# %%
'''Categorizing all the tariff data US announced and write them into excel sheet.'''

import re
import xlsxwriter

'''two txt files''' 
#china.txt
#us.txt

us = open('us.txt')
rus = us.read()

#return all the commodity categories, names and volumes
um = re.findall('<li class=item__(.*?) data-dollareffect=(.*?)> <span class=item__bullet>•</span> <span class=item__name>(.*?)</span> </li>',rus,re.DOTALL)

#seperate the list above by category
ualist = list()
for uia in um:
    if uia[0] == 'agriculture':
        ualist.append(uia)
uelist = list()
for uie in um:
    if uie[0] == 'energy':
        uelist.append(uie)
uilist = list()
for uii in um:
    if uii[0] == 'industrials':
        uilist.append(uii)
utlist = list()
for uit in um:
    if uit[0] == 'transport':
        utlist.append(uit)
uolist = list()
for uio in um:
    if uio[0] == 'others':
        uolist.append(uio)

#get total number of each categories' commodities  
luma=len(ualist)
lume=len(uelist)
lumi=len(uilist)
lumt=len(utlist)
lumo=len(uolist)

#return all the dollar volumes into 5 lists seperated based on catergories
#and convert all the dollar volume into integer
uanumlist = list()
for uaitem in ualist:
    uanum = uaitem[1]
    uanumlist.append(uanum)
uanumlist2 =list()
for uaitem2 in uanumlist:
    if uaitem2 == '""':
        uaitem2 = int(0)
        uanumlist2.append(int(uaitem2))
    else:
        uaitem2 == uaitem2
        uanumlist2.append(int(uaitem2))

uenumlist = list()
for ueitem in uelist:
    uenum = ueitem[1]
    uenumlist.append(uenum)
uenumlist2 =list()
for ueitem2 in uenumlist:
    if ueitem2 == '""':
        ueitem2 = int(0)
        uenumlist2.append(int(ueitem2))
    else:
        ueitem2 == ueitem2
        uenumlist2.append(int(ueitem2))

uinumlist = list()
for uiitem in uilist:
    uinum = uiitem[1]
    uinumlist.append(uinum)
uinumlist2 =list()
for uiitem2 in uinumlist:
    if uiitem2 == '""':
        uiitem2 = int(0)
        uinumlist2.append(int(uiitem2))
    else:
        uiitem2 == uiitem2
        uinumlist2.append(int(uiitem2))        
        
utnumlist = list()
for utitem in utlist:
    utnum = utitem[1]
    utnumlist.append(utnum)
utnumlist2 =list()
for utitem2 in utnumlist:
    if utitem2 == '""':
        utitem2 = int(0)
        utnumlist2.append(int(utitem2))
    else:
        utitem2 == utitem2
        utnumlist2.append(int(utitem2))
        
uonumlist = list()
for uoitem in uolist:
    uonum = uoitem[1]
    uonumlist.append(uonum)
uonumlist2 =list()
for uoitem2 in uonumlist:
    if uoitem2 == '""':
        uoitem2 = int(0)
        uonumlist2.append(int(uoitem2))
    else:
        uoitem2 == uoitem2
        uonumlist2.append(int(uoitem2))        
        
#return all the commodity names into 5 lists seperated based on catergories
uacomlist = list()
for uac in ualist:
    uacom = uac[2]
    uacomlist.append(uacom)
uecomlist = list()
for uec in uelist:
    uecom = uec[2]
    uecomlist.append(uecom)
uicomlist = list()
for uic in uilist:
    uicom = uic[2]
    uicomlist.append(uicom)
utcomlist = list()
for utc in utlist:
    utcom = utc[2]
    utcomlist.append(utcom)
uocomlist = list()
for uoc in uolist:
    uocom = uoc[2]
    uocomlist.append(uocom)

    
#convert the volume and name back together into one list of tuple, for the preparation of sorting
#after finishing sorting, seperate the volume and name items again into 2 lists
uforsortinga = zip(uanumlist2,uacomlist)
uforsortinga = set(uforsortinga)
usortinga = sorted(uforsortinga, key=lambda ufa: ufa[0], reverse = True)
usanumlist = list()    
usacomlist = list()
for usaitem in usortinga:
    usanum = usaitem[0]
    usanumlist.append(usanum)
for usac in usortinga:
    usacom = usac[1]
    usacomlist.append(usacom)

uforsortinge = zip(uenumlist2,uecomlist)
uforsortinge = set(uforsortinge)
usortinge = sorted(uforsortinge, key=lambda ufe: ufe[0], reverse = True)
usenumlist = list()    
usecomlist = list()
for useitem in usortinge:
    usenum = useitem[0]
    usenumlist.append(usenum)
for usec in usortinge:
    usecom = usec[1]
    usecomlist.append(usecom)   

uforsortingi = zip(uinumlist2,uicomlist)
uforsortingi = set(uforsortingi)
usortingi = sorted(uforsortingi, key=lambda ufi: ufi[0], reverse = True)
usinumlist = list()    
usicomlist = list()
for usiitem in usortingi:
    usinum = usiitem[0]
    usinumlist.append(usinum)
for usic in usortingi:
    usicom = usic[1]
    usicomlist.append(usicom) 
    
uforsortingt = zip(utnumlist2,utcomlist)
uforsortingt = set(uforsortingt)
usortingt = sorted(uforsortingt, key=lambda uft: uft[0], reverse = True)
ustnumlist = list()    
ustcomlist = list()
for ustitem in usortingt:
    ustnum = ustitem[0]
    ustnumlist.append(ustnum)
for ustc in usortingt:
    ustcom = ustc[1]
    ustcomlist.append(ustcom) 
    
uforsortingo = zip(uonumlist2,uocomlist)
uforsortingo = set(uforsortingo)
usortingo = sorted(uforsortingo, key=lambda ufo: ufo[0], reverse = True)
usonumlist = list()    
usocomlist = list()
for usoitem in usortingo:
    usonum = usoitem[0]
    usonumlist.append(usonum)
for usoc in usortingo:
    usocom = usoc[1]
    usocomlist.append(usocom) 

#write all the content and number into a excel book
#workbook = xlsxwriter.Workbook('tariffs2.xlsx')
worksheet2 = workbook.add_worksheet('tus')

worksheet2.write(0,0,'AGRICULTURE')
worksheet2.write(0,1,luma)
worksheet2.write(1,0,'Commodity')
worksheet2.write(1,1,'Dollar Volume')
worksheet2.write_column(2,1,usanumlist)
worksheet2.write_column(2,0,usacomlist)

worksheet2.write(0,2,'ENERGY')
worksheet2.write(0,3,lume)
worksheet2.write(1,2,'Commodity')
worksheet2.write(1,3,'Dollar Volume')
worksheet2.write_column(2,3,usenumlist)
worksheet2.write_column(2,2,usecomlist)

worksheet2.write(0,4,'INDUSTRIALS/TECHNOLOGY')
worksheet2.write(0,5,lumi)
worksheet2.write(1,4,'Commodity')
worksheet2.write(1,5,'Dollar Volume')
worksheet2.write_column(2,5,usinumlist)
worksheet2.write_column(2,4,usicomlist)

worksheet2.write(0,6,'TRANSPORT')
worksheet2.write(0,7,lumt)
worksheet2.write(1,6,'Commodity')
worksheet2.write(1,7,'Dollar Volume')
worksheet2.write_column(2,7,ustnumlist)
worksheet2.write_column(2,6,ustcomlist)

worksheet2.write(0,8,'OTHERS')
worksheet2.write(0,9,lumo)
worksheet2.write(1,8,'Commodity')
worksheet2.write(1,9,'Dollar Volume')
worksheet2.write_column(2,9,usonumlist)
worksheet2.write_column(2,8,usocomlist)

workbook.close()

# %% [markdown]
# ## ABANDONED CODE

# %%
'''
wlist = list()
for i in whole:
    if i[1] != '""':
        wlist.append(i)
print(wlist)
'''
